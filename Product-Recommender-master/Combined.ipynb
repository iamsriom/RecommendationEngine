# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet

import warnings; warnings.simplefilter('ignore')

# %%
# all lightfm imports 
from lightfm.data import Dataset
from lightfm import LightFM
from lightfm import cross_validation
from lightfm.evaluation import precision_at_k
from lightfm.evaluation import auc_score

# imports re for text cleaning 
import re
from datetime import datetime, timedelta

# %% [markdown]
# # Loading Dataset

# %%
ordersExport = pd.read_csv('orders_export.csv')
productsExport = pd.read_csv('products_export.csv')

# %%
df_order = ordersExport[['Name', 'Lineitem quantity', 'Lineitem name', 'Lineitem sku']]
print(df_order.shape)
df_order.head()
# Out:
# (118, 4)
#     Name  Lineitem quantity           Lineitem name Lineitem sku
# 0  #2891                  1        Betwa Kurta - XL      HOD0011
# 1  #2891                  1  Bhagirathi pants - XXL      HOD0444
# 2  #2891                  1         Kosi Kurta - XL      HOD0005
# 3  #2892                  1     Panzara kurta - XXL      HOD0126
# 4  #2893                  1         Betwa Kurta - S      HOD0008

# %%
df_product = productsExport[['Handle', 'Title', 'Custom Product Type', 'Tags', 'Variant SKU']]
print(df_product.shape)
df_product.head()
# Out:
# (874, 5)
#                          Handle                                 Title  \
# 0  ishya-blockprinted-kurta-set  Ishya Blockprinted Kurta  (Set of 2)
# 1  ishya-blockprinted-kurta-set                                   NaN
# 2  ishya-blockprinted-kurta-set                                   NaN
# 3  ishya-blockprinted-kurta-set                                   NaN
# 4  ishya-blockprinted-kurta-set                                   NaN
#
#   Custom Product Type                                               Tags  \
# 0          Kurta Sets  Category_Kurta Sets, Category_Women, Collectio...
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#   Variant SKU
# 0     HOD0772
# 1     HOD0773
# 2     HOD0774
# 3     HOD0775
# 4     HOD0776

# %%
final_product = df_product[df_product['Tags'].isnull() == False]
print(final_product.shape)
final_product
# Out:
# (163, 5)
#                                   Handle  \
# 0           ishya-blockprinted-kurta-set
# 10         ahaana-blockprinted-kurta-set
# 21          seher-blockprinted-kurta-set
# 29         mihira-blockprinted-kurta-set
# 41          bahar-blockprinted-kurta-set
# ..                                   ...
# 844          a-line-white-and-blue-kurta
# 850  long-straight-peach-and-white-kurta
# 856            long-straight-white-kurta
# 862            straight-blue-white-kurta
# 868                      peachful-desire
#
#                                     Title Custom Product Type  \
# 0    Ishya Blockprinted Kurta  (Set of 2)          Kurta Sets
# 10   Ahaana Blockprinted Kurta (Set of 2)          Kurta Sets
# 21    Seher Blockprinted Kurta (Set of 2)          Kurta Sets
# 29   Mihira Blockprinted Kurta (Set of 3)          Kurta Sets
# 41    Bahar Blockprinted Kurta (Set of 3)          Kurta Sets
# ..                                    ...                 ...
# 844                          Sutlej Kurta               Kurta
# 850                          Chenab Kurta               Kurta
# 856                       Alaknanda Kurta               Kurta
# 862                           Betwa Kurta               Kurta
# 868                            Kosi Kurta               Kurta
#
#                                                   Tags Variant SKU
# 0    Category_Kurta Sets, Category_Women, Collectio...     HOD0772
# 10   Category_Kurta Sets, Category_Women, Collectio...     HOD0766
# 21   Category_Kurta Sets, Category_Women, Collectio...     HOD0760
# 29   Category_Kurta Sets, Category_Women, Collectio...     HOD0754
# 41   Category_Kurta Sets, Category_Women, Collectio...     HOD0748
# ..                                                 ...         ...
# 844  Category_Kurta, Category_Women, Collection_Nad...     HOD0025
# 850  Category_Kurta, Category_Women, Collection_Nad...     HOD0019
# 856  Category_Kurta, Category_Women, Collection_Nad...     HOD0013
# 862  Category_Kurta, Category_Women, Collection_Nad...     HOD0007
# 868  Category_Kurta, Category_Women, Collection_Nad...     HOD0001
#
# [163 rows x 5 columns]

# %% [markdown]
# # Generating Function

# %%
def generate_int_id(dataframe, id_col_name):
    new_dataframe=dataframe.assign(
        int_id_col_name=np.arange(len(dataframe))
        ).reset_index(drop=True)
    return new_dataframe.rename(columns={'int_id_col_name': id_col_name})



def create_features(dataframe, features_name, id_col_name):
    features = dataframe[features_name].apply(
        lambda x: ','.join(x.map(str)), axis=1)
    features = features.str.split(',')
    features = list(zip(dataframe[id_col_name], features))
    return features



def generate_feature_list(dataframe, features_name):
    features = dataframe[features_name].apply(
        lambda x: ','.join(x.map(str)), axis=1)
    features = features.str.split(',')
    features = features.apply(pd.Series).stack().reset_index(drop=True)
    return features


def calculate_auc_score(lightfm_model, interactions_matrix, question_features, professional_features): 
    score = auc_score( 
        lightfm_model, interactions_matrix, 
        item_features=question_features, 
        user_features=professional_features, 
        num_threads=4).mean()
    return score

# %% [markdown]
# # Cleaning

# %%
final_product['Handle'] = final_product['Handle'].apply(lambda x: [str.lower(i.replace("-", "")) for i in x])
final_product['Handle'] = final_product['Handle'].apply(lambda x: ''.join(x))
final_product['Handle']
# Out:
# 0           ishyablockprintedkurtaset
# 10         ahaanablockprintedkurtaset
# 21          seherblockprintedkurtaset
# 29         mihirablockprintedkurtaset
# 41          baharblockprintedkurtaset
#                     ...
# 844            alinewhiteandbluekurta
# 850    longstraightpeachandwhitekurta
# 856            longstraightwhitekurta
# 862            straightbluewhitekurta
# 868                    peachfuldesire
# Name: Handle, Length: 163, dtype: object

# %%
final_product['Title'] = final_product['Title'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
final_product['Title'] = final_product['Title'].apply(lambda x: ''.join(x))
final_product['Title'][0:10]
# Out:
# 0      ishyablockprintedkurta(setof2)
# 10    ahaanablockprintedkurta(setof2)
# 21     seherblockprintedkurta(setof2)
# 29    mihirablockprintedkurta(setof3)
# 41     baharblockprintedkurta(setof3)
# 55      keyablockprintedkurta(setof3)
# 70                         ektakaftan
# 76                        barnakaftan
# 82                   saukhayadakaftan
# 88                       chesnakaftan
# Name: Title, dtype: object

# %%
final_product['Tags'] = final_product['Tags'].apply(lambda x: [str.lower(i.replace("_", "")) for i in x])
final_product['Tags'] = final_product['Tags'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
final_product['Tags'] = final_product['Tags'].apply(lambda x: ''.join(x))
final_product['Tags'] = final_product['Tags'].apply(lambda x: [str.lower(i.replace(",", " ")) for i in x])
final_product['Tags'] = final_product['Tags'].apply(lambda x: ''.join(x))
final_product['Tags'][0]
# Out:
# 'categorykurtasets categorywomen collectionrozana kurtaforwomen necktypevneck price3kto4k'

# %% [markdown]
# ## Combining

# %%
final_product['description'] = final_product['Handle'] + " " + final_product['Title'] + " " + final_product['Tags']
final_product['description'] = final_product['description'].fillna('')
final_product['description'][0]
# Out:
# 'ishyablockprintedkurtaset ishyablockprintedkurta(setof2) categorykurtasets categorywomen collectionrozana kurtaforwomen necktypevneck price3kto4k'

# %%
import re

def clean_description(text):
    text = re.sub("\'", "", text)
#     text = re.sub("[^a-zA-Z]"," ",text)
    text = ' '.join(text.split()).replace(' ', ',')
    text = text.lower()
    return text

final_product['clean_description'] = final_product['description'].apply(lambda x: clean_description(x))
final_product['clean_description'][0]
# Out:
# 'ishyablockprintedkurtaset,ishyablockprintedkurta(setof2),categorykurtasets,categorywomen,collectionrozana,kurtaforwomen,necktypevneck,price3kto4k'

# %%
final_product.head()
# Out:
#                         Handle                            Title  \
# 0    ishyablockprintedkurtaset   ishyablockprintedkurta(setof2)
# 10  ahaanablockprintedkurtaset  ahaanablockprintedkurta(setof2)
# 21   seherblockprintedkurtaset   seherblockprintedkurta(setof2)
# 29  mihirablockprintedkurtaset  mihirablockprintedkurta(setof3)
# 41   baharblockprintedkurtaset   baharblockprintedkurta(setof3)
#
#    Custom Product Type                                               Tags  \
# 0           Kurta Sets  categorykurtasets categorywomen collectionroza...
# 10          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 21          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 29          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 41          Kurta Sets  categorykurtasets categorywomen collectionroza...
#
#    Variant SKU                                        description  \
# 0      HOD0772  ishyablockprintedkurtaset ishyablockprintedkur...
# 10     HOD0766  ahaanablockprintedkurtaset ahaanablockprintedk...
# 21     HOD0760  seherblockprintedkurtaset seherblockprintedkur...
# 29     HOD0754  mihirablockprintedkurtaset mihirablockprintedk...
# 41     HOD0748  baharblockprintedkurtaset baharblockprintedkur...
#
#                                     clean_description
# 0   ishyablockprintedkurtaset,ishyablockprintedkur...
# 10  ahaanablockprintedkurtaset,ahaanablockprintedk...
# 21  seherblockprintedkurtaset,seherblockprintedkur...
# 29  mihirablockprintedkurtaset,mihirablockprintedk...
# 41  baharblockprintedkurtaset,baharblockprintedkur...

# %% [markdown]
# ## Adding Product ID

# %%
final_product = generate_int_id(final_product, 'product_id_num')
final_product.head()
# Out:
#                        Handle                            Title  \
# 0   ishyablockprintedkurtaset   ishyablockprintedkurta(setof2)
# 1  ahaanablockprintedkurtaset  ahaanablockprintedkurta(setof2)
# 2   seherblockprintedkurtaset   seherblockprintedkurta(setof2)
# 3  mihirablockprintedkurtaset  mihirablockprintedkurta(setof3)
# 4   baharblockprintedkurtaset   baharblockprintedkurta(setof3)
#
#   Custom Product Type                                               Tags  \
# 0          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 1          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 2          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 3          Kurta Sets  categorykurtasets categorywomen collectionroza...
# 4          Kurta Sets  categorykurtasets categorywomen collectionroza...
#
#   Variant SKU                                        description  \
# 0     HOD0772  ishyablockprintedkurtaset ishyablockprintedkur...
# 1     HOD0766  ahaanablockprintedkurtaset ahaanablockprintedk...
# 2     HOD0760  seherblockprintedkurtaset seherblockprintedkur...
# 3     HOD0754  mihirablockprintedkurtaset mihirablockprintedk...
# 4     HOD0748  baharblockprintedkurtaset baharblockprintedkur...
#
#                                    clean_description  product_id_num
# 0  ishyablockprintedkurtaset,ishyablockprintedkur...               0
# 1  ahaanablockprintedkurtaset,ahaanablockprintedk...               1
# 2  seherblockprintedkurtaset,seherblockprintedkur...               2
# 3  mihirablockprintedkurtaset,mihirablockprintedk...               3
# 4  baharblockprintedkurtaset,baharblockprintedkur...               4

# %%
final_productdf = final_product[['Variant SKU','product_id_num','Title','clean_description']]
final_productdf = final_productdf.rename(columns={'clean_description': 'item_tag_name'})
final_productdf
# Out:
#     Variant SKU  product_id_num                            Title  \
# 0       HOD0772               0   ishyablockprintedkurta(setof2)
# 1       HOD0766               1  ahaanablockprintedkurta(setof2)
# 2       HOD0760               2   seherblockprintedkurta(setof2)
# 3       HOD0754               3  mihirablockprintedkurta(setof3)
# 4       HOD0748               4   baharblockprintedkurta(setof3)
# ..          ...             ...                              ...
# 158     HOD0025             158                      sutlejkurta
# 159     HOD0019             159                      chenabkurta
# 160     HOD0013             160                   alaknandakurta
# 161     HOD0007             161                       betwakurta
# 162     HOD0001             162                        kosikurta
#
#                                          item_tag_name
# 0    ishyablockprintedkurtaset,ishyablockprintedkur...
# 1    ahaanablockprintedkurtaset,ahaanablockprintedk...
# 2    seherblockprintedkurtaset,seherblockprintedkur...
# 3    mihirablockprintedkurtaset,mihirablockprintedk...
# 4    baharblockprintedkurtaset,baharblockprintedkur...
# ..                                                 ...
# 158  alinewhiteandbluekurta,sutlejkurta,categorykur...
# 159  longstraightpeachandwhitekurta,chenabkurta,cat...
# 160  longstraightwhitekurta,alaknandakurta,category...
# 161  straightbluewhitekurta,betwakurta,categorykurt...
# 162  peachfuldesire,kosikurta,categorykurta,categor...
#
# [163 rows x 4 columns]

# %% [markdown]
# # Content Based Recommender

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
count_matrix = count.fit_transform(final_productdf['item_tag_name'])

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
sku = final_productdf['Variant SKU']
sku
# Out:
# 0      HOD0772
# 1      HOD0766
# 2      HOD0760
# 3      HOD0754
# 4      HOD0748
#         ...
# 158    HOD0025
# 159    HOD0019
# 160    HOD0013
# 161    HOD0007
# 162    HOD0001
# Name: Variant SKU, Length: 163, dtype: object

# %%
indices = pd.Series(final_product.index, index=final_product['Title'])
indices
# Out:
# Title
# ishyablockprintedkurta(setof2)       0
# ahaanablockprintedkurta(setof2)      1
# seherblockprintedkurta(setof2)       2
# mihirablockprintedkurta(setof3)      3
# baharblockprintedkurta(setof3)       4
#                                   ...
# sutlejkurta                        158
# chenabkurta                        159
# alaknandakurta                     160
# betwakurta                         161
# kosikurta                          162
# Length: 163, dtype: int64

# %% [markdown]
# # Hybrid Recommender (LightFM)

# %%
df_order.head()
# Out:
#     Name  Lineitem quantity           Lineitem name Lineitem sku
# 0  #2891                  1        Betwa Kurta - XL      HOD0011
# 1  #2891                  1  Bhagirathi pants - XXL      HOD0444
# 2  #2891                  1         Kosi Kurta - XL      HOD0005
# 3  #2892                  1     Panzara kurta - XXL      HOD0126
# 4  #2893                  1         Betwa Kurta - S      HOD0008

# %%
df_merge = df_order.merge(final_productdf, how='inner', left_on='Lineitem sku', right_on='Variant SKU')
df_merge['Name'] = df_merge['Name'].str.replace('#', '')
print(df_merge.shape)
df_merge
# Out:
# (32, 8)
#     Name  Lineitem quantity                              Lineitem name  \
# 0   2898                  1                 Green Car Cotton Shirt - S
# 1   2898                  1                Light Blue Cotton Shirt - S
# 2   2932                  1                Light Blue Cotton Shirt - S
# 3   2898                  1               Olive Green Cotton Shirt - S
# 4   2898                  1                Red Flower Cotton Shirt - S
# 5   2898                  1            Maroon Scooter Cotton Shirt - S
# 6   2906                  1                             Pavana dupatta
# 7   2907                  1                          Vaigai kurta - XS
# 8   2907                  1                            Vaighai dupatta
# 9   2939                  1                            Vaighai dupatta
# 10  2909                  1                      Pink Cotton Shirt - S
# 11  2909                  1                      Grey Cotton Shirt - S
# 12  2910                  1                           Tapti pants - XS
# 13  2910                  1  Mihira Blockprinted Kurta (Set of 3) - XS
# 14  2910                  1    Keya Blockprinted Kurta (Set of 3) - XS
# 15  2910                  1   Bahar Blockprinted Kurta (Set of 3) - XS
# 16  2921                  1   Bahar Blockprinted Kurta (Set of 3) - XS
# 17  2923                  1                           Pranhita dupatta
# 18  2928                  1                           Chaliyar Dupatta
# 19  2929                  1                            Doda Kurta - XS
# 20  2929                  1                            Dras kurta - XS
# 21  2935                  1                            Dras kurta - XS
# 22  2929                  1                           Palar Kurta - XS
# 23  2929                  1                         Damodar Kurta - XS
# 24  2929                  1  Ishya Blockprinted Kurta  (Set of 2) - XS
# 25  2929                  1  Ahaana Blockprinted Kurta (Set of 2) - XS
# 26  2933                  1                           Gomai Kurta - XS
# 27  2933                  1                          Hoogly Kurta - XS
# 28  2933                  1                           Betwa Kurta - XS
# 29  2935                  1                       Manjira palazzo - XS
# 30  2935                  1                      Hemavati palazzo - XS
# 31  2935                  1                        Hemavati kurta - XS
#
#    Lineitem sku Variant SKU  product_id_num                            Title  \
# 0       HOD0607     HOD0607              40              greencarcottonshirt
# 1       HOD0575     HOD0575              48             lightbluecottonshirt
# 2       HOD0575     HOD0575              48             lightbluecottonshirt
# 3       HOD0579     HOD0579              47            olivegreencottonshirt
# 4       HOD0615     HOD0615              38             redflowercottonshirt
# 5       HOD0635     HOD0635              33         maroonscootercottonshirt
# 6       HOD0544     HOD0544              84                    pavanadupatta
# 7       HOD0103     HOD0103             139                      vaigaikurta
# 8       HOD0542     HOD0542              87                   vaighaidupatta
# 9       HOD0542     HOD0542              87                   vaighaidupatta
# 10      HOD0631     HOD0631              34                  pinkcottonshirt
# 11      HOD0647     HOD0647              30                  greycottonshirt
# 12      HOD0433     HOD0433             107                       taptipants
# 13      HOD0754     HOD0754               3  mihirablockprintedkurta(setof3)
# 14      HOD0742     HOD0742               5    keyablockprintedkurta(setof3)
# 15      HOD0748     HOD0748               4   baharblockprintedkurta(setof3)
# 16      HOD0748     HOD0748               4   baharblockprintedkurta(setof3)
# 17      HOD0548     HOD0548              78                  pranhitadupatta
# 18      HOD0538     HOD0538              92                  chaliyardupatta
# 19      HOD0037     HOD0037             156                        dodakurta
# 20      HOD0079     HOD0079             148                        draskurta
# 21      HOD0079     HOD0079             148                        draskurta
# 22      HOD0229     HOD0229              81                       palarkurta
# 23      HOD0271     HOD0271              65                     damodarkurta
# 24      HOD0772     HOD0772               0   ishyablockprintedkurta(setof2)
# 25      HOD0766     HOD0766               1  ahaanablockprintedkurta(setof2)
# 26      HOD0217     HOD0217              86                       gomaikurta
# 27      HOD0031     HOD0031             157                      hooglykurta
# 28      HOD0007     HOD0007             161                       betwakurta
# 29      HOD0421     HOD0421             109                   manjirapalazzo
# 30      HOD0397     HOD0397             113                  hemavatipalazzo
# 31      HOD0157     HOD0157             123                    hemavatikurta
#
#                                         item_tag_name
# 0   greencarcottonshirt,greencarcottonshirt,catego...
# 1   lightbluecottonshirt,lightbluecottonshirt,cate...
# 2   lightbluecottonshirt,lightbluecottonshirt,cate...
# 3   olivegreencottonshirt,olivegreencottonshirt,ca...
# 4   redflowercottonshirt,redflowercottonshirt,cate...
# 5   maroonscootercottonshirt,maroonscootercottonsh...
# 6   pavanadupatta,pavanadupatta,categorydupatta,ca...
# 7   vaigaikurta,vaigaikurta,categorykurta,category...
# 8   vaighaidupatta,vaighaidupatta,categorydupatta,...
# 9   vaighaidupatta,vaighaidupatta,categorydupatta,...
# 10  pinkcottonshirt,pinkcottonshirt,categorymen,ca...
# 11  greycottonshirt,greycottonshirt,categorymen,ca...
# 12  taptipant,taptipants,categorypants,categorywom...
# 13  mihirablockprintedkurtaset,mihirablockprintedk...
# 14  keyablockprintedkurtaset,keyablockprintedkurta...
# 15  baharblockprintedkurtaset,baharblockprintedkur...
# 16  baharblockprintedkurtaset,baharblockprintedkur...
# 17  pranhitadupatta,pranhitadupatta,categorydupatt...
# 18  narmadadupatta,chaliyardupatta,categorydupatta...
# 19  longstraightbrowncolor,dodakurta,categorykurta...
# 20  draskurta,draskurta,categorykurta,categorywome...
# 21  draskurta,draskurta,categorykurta,categorywome...
# 22  palarkurta,palarkurta,categorykurta,categorywo...
# 23  damodarkurta,damodarkurta,categorykurta,catego...
# 24  ishyablockprintedkurtaset,ishyablockprintedkur...
# 25  ahaanablockprintedkurtaset,ahaanablockprintedk...
# 26  gomaikurta,gomaikurta,categorykurta,categorywo...
# 27  alinewhiteandantiquemoss,hooglykurta,categoryk...
# 28  straightbluewhitekurta,betwakurta,categorykurt...
# 29  manjirapalazzo,manjirapalazzo,categorypants,ca...
# 30  hemavatipalazzo,hemavatipalazzo,categorypants,...
# 31  hemavatikurta,hemavatikurta,categorykurta,cate...

# %%
user_tag = df_merge.groupby(['Name'])['item_tag_name'].apply(','.join).reset_index()
user_tag = user_tag.rename(columns={'item_tag_name': 'user_tag_name'})
user_tag = generate_int_id(user_tag, 'order_id_num')
user_tag
# Out:
#     Name                                      user_tag_name  order_id_num
# 0   2898  greencarcottonshirt,greencarcottonshirt,catego...             0
# 1   2906  pavanadupatta,pavanadupatta,categorydupatta,ca...             1
# 2   2907  vaigaikurta,vaigaikurta,categorykurta,category...             2
# 3   2909  pinkcottonshirt,pinkcottonshirt,categorymen,ca...             3
# 4   2910  taptipant,taptipants,categorypants,categorywom...             4
# 5   2921  baharblockprintedkurtaset,baharblockprintedkur...             5
# 6   2923  pranhitadupatta,pranhitadupatta,categorydupatt...             6
# 7   2928  narmadadupatta,chaliyardupatta,categorydupatta...             7
# 8   2929  longstraightbrowncolor,dodakurta,categorykurta...             8
# 9   2932  lightbluecottonshirt,lightbluecottonshirt,cate...             9
# 10  2933  gomaikurta,gomaikurta,categorykurta,categorywo...            10
# 11  2935  draskurta,draskurta,categorykurta,categorywome...            11
# 12  2939  vaighaidupatta,vaighaidupatta,categorydupatta,...            12

# %%
final_merge = df_merge.merge(user_tag, how='inner', left_on='Name', right_on='Name')
print(final_merge.shape)
final_merge.head()
# Out:
# (32, 10)
#    Name  Lineitem quantity                    Lineitem name Lineitem sku  \
# 0  2898                  1       Green Car Cotton Shirt - S      HOD0607
# 1  2898                  1      Light Blue Cotton Shirt - S      HOD0575
# 2  2898                  1     Olive Green Cotton Shirt - S      HOD0579
# 3  2898                  1      Red Flower Cotton Shirt - S      HOD0615
# 4  2898                  1  Maroon Scooter Cotton Shirt - S      HOD0635
#
#   Variant SKU  product_id_num                     Title  \
# 0     HOD0607              40       greencarcottonshirt
# 1     HOD0575              48      lightbluecottonshirt
# 2     HOD0579              47     olivegreencottonshirt
# 3     HOD0615              38      redflowercottonshirt
# 4     HOD0635              33  maroonscootercottonshirt
#
#                                        item_tag_name  \
# 0  greencarcottonshirt,greencarcottonshirt,catego...
# 1  lightbluecottonshirt,lightbluecottonshirt,cate...
# 2  olivegreencottonshirt,olivegreencottonshirt,ca...
# 3  redflowercottonshirt,redflowercottonshirt,cate...
# 4  maroonscootercottonshirt,maroonscootercottonsh...
#
#                                        user_tag_name  order_id_num
# 0  greencarcottonshirt,greencarcottonshirt,catego...             0
# 1  greencarcottonshirt,greencarcottonshirt,catego...             0
# 2  greencarcottonshirt,greencarcottonshirt,catego...             0
# 3  greencarcottonshirt,greencarcottonshirt,catego...             0
# 4  greencarcottonshirt,greencarcottonshirt,catego...             0

# %%
user_feature_list = generate_feature_list(user_tag,['user_tag_name'])

item_feature_list = generate_feature_list(final_productdf,['item_tag_name'])

# %%
user_tag['user_features'] = create_features(user_tag, ['user_tag_name'], 'order_id_num')
final_productdf['item_features'] = create_features(final_productdf,['item_tag_name'],'product_id_num')

# %%
dataset = Dataset()
dataset.fit(
    set(user_tag['order_id_num']),
    set(final_productdf['product_id_num']), 
    item_features=item_feature_list, 
    user_features=user_feature_list)

# %%
final_merge['user_item_id_tuple'] = list(zip(final_merge.order_id_num, final_merge.product_id_num))

# %%
interactions, weights = dataset.build_interactions(final_merge['user_item_id_tuple'])

# %%
item_features = dataset.build_item_features(final_productdf['item_features'])
user_features = dataset.build_user_features(user_tag['user_features'])

# %%
model = LightFM(
    no_components=150,
    learning_rate=0.05,
    loss='warp',
    random_state=2019)

model.fit(
    interactions,
    item_features=item_features,
    user_features=user_features, sample_weight=weights,
    epochs=5, num_threads=4, verbose=True)
# Out:
# Epoch: 100%|████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 104.23it/s]

# %%
calculate_auc_score(model, interactions, item_features, user_features)
# Out:
# 0.87400055

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

def recommend_item(input):
    if (type(input) == int):

            # print their previous answered question title
            previous_item_num = final_merge.loc[final_merge['order_id_num'] == input][:3]['product_id_num']
            df_previous_items = final_productdf.loc[final_productdf['product_id_num'].isin(previous_item_num)]
            print('User Id (' + str(input) + "): Previous Item Purchased")
            display_side_by_side(
                df_previous_items[['product_id_num', 'item_features']],
                user_tag.loc[user_tag.order_id_num == input][['order_id_num','user_tag_name']])

            # predict
            discard_qu_id = df_previous_items['product_id_num'].values.tolist()
            df_use_for_prediction = final_productdf.loc[~final_productdf['product_id_num'].isin(discard_qu_id)]
            items_id_for_predict = df_use_for_prediction['product_id_num'].values.tolist()

            scores = model.predict(
                input,
                items_id_for_predict,
                item_features=item_features,
                user_features=user_features)

            df_use_for_prediction['scores'] = scores
            df_use_for_prediction = df_use_for_prediction.sort_values(by='scores', ascending=False)[:8]
            print()
            print('User Id (' + str(input) + "): Recommended Item: ")
            display(df_use_for_prediction[['product_id_num', 'item_features', 'Variant SKU']])

    else:
            idx = indices[input]

            #It will get the title with its index
            sim_scores = list(enumerate(cosine_sim[idx]))

            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
            sim_scores = sim_scores[1:6]

            # [2502, 7535, 4702, 889, 437]
            product_indices = [i[0] for i in sim_scores]

            print(sku.iloc[product_indices])

# %%
recommend_item("chenabkurta")
# Out:
# 162    HOD0001
# 99     HOD0181
# 160    HOD0013
# 126    HOD0145
# 154    HOD0049
# Name: Variant SKU, dtype: object

# %%
recommend_item(7)
# Out:
# User Id (7): Previous Item Purchased
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id_num</th>
#       <th>item_features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>92</th>
#       <td>92</td>
#       <td>(92, [narmadadupatta, chaliyardupatta, categorydupatta, categorywomen, collectionnadiyankinare, colororange, price1kto2k, sale, stylekotadoriya])</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id_num</th>
#       <th>user_tag_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>narmadadupatta,chaliyardupatta,categorydupatta,categorywomen,collectionnadiyankinare,colororange,price1kto2k,sale,stylekotadoriya</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# User Id (7): Recommended Item:
#     product_id_num                                      item_features  \
# 4                4  (4, [baharblockprintedkurtaset, baharblockprin...
# 3                3  (3, [mihirablockprintedkurtaset, mihirablockpr...
# 0                0  (0, [ishyablockprintedkurtaset, ishyablockprin...
# 5                5  (5, [keyablockprintedkurtaset, keyablockprinte...
# 1                1  (1, [ahaanablockprintedkurtaset, ahaanablockpr...
# 2                2  (2, [seherblockprintedkurtaset, seherblockprin...
# 48              48  (48, [lightbluecottonshirt, lightbluecottonshi...
# 47              47  (47, [olivegreencottonshirt, olivegreencottons...
#
#    Variant SKU
# 4      HOD0748
# 3      HOD0754
# 0      HOD0772
# 5      HOD0742
# 1      HOD0766
# 2      HOD0760
# 48     HOD0575
# 47     HOD0579
